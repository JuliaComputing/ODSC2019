# %% [markdown]
# # How To Aim Your Flagon

# %% [markdown]
# ## Loading your Trebuchet

# %% [markdown]
# ###### Use this version of the notebook if using Julia 1.3rc5 or later -- needs Flux#master

# %% [markdown]
# Today we practice the ancient medieval art of throwing stuff. First up, we load our trebuchet simulator, Trebuchet.jl.

# %%
using Trebuchet

# %% [markdown]
# We can see what the trebuchet looks like, by explicitly creating a trebuchet state, running a simulation, and visualising the trajectory.

# %%
t = TrebuchetState()
simulate(t)
visualise(t)
# Out:
# WebIO.Scope(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :span), Any[], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}(), Set(String[]), nothing, WebIO.Asset[WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/utils.js"), WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/animate.js"), WebIO.Asset("css", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/css/basic.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(WebIO.AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x00007fc8b7fde4a0, Task (runnable) @0x00007fc8b7fde4a0), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (){createCanvas(this.dom,\"main\"); createOutputBar(this.dom,\"output\",{\"distance\":[0.0,\"m\"],\"height\":[0.0,\"m\"],\"time\":[0.0,\"m\"],\"wind_speed\":[1.0,\"m/s\"],\"release_angle\":[44.99999999999999,\"deg\"]}); return animate(this.dom,\"main\",{\"a\":1.524,\"b\":2.0702016,\"c\":0.5334,\"d\":0.6096,\"e\":2.0826984,\"u\":0.8311896,\"z\":0.037947600000000005},{\"WeightCG\":[[0.36100903572858956,-0.21693215547703187],[0.36100903572858956,-0.21693215547703187],[0.36121169080754156,-0.21826469278794586],[0.36160626877022745,-0.22093699304505876],[0.36218188378492033,-0.22496236727324898],[0.36292728001748314,-0.23036013774467917],[0.363830503182816,-0.23715552725618172],[0.3648784778937668,-0.24537947672165983],[0.3660565171858164,-0.25506834641565734],[0.36734780045985344,-0.26626345094104703],[0.3687328664785807,-0.2790103784357236],[0.37018917737896506,-0.29335805181148567],[0.3716908156413523,-0.3093575043939808],[0.37320837591490047,-0.32706036351445295],[0.37470910504905564,-0.3465170610807403],[0.376157325125258,-0.3677748156896181],[0.3775151461429256,-0.39087545027069015],[0.3787434404287933,-0.41585311481724135],[0.3798030160902147,-0.442731966556288],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.38065590130945604,-0.4715238097076727],[0.3812663642530947,-0.5022266626654668],[0.38160133670624774,-0.5348243481507587],[0.38163097239335414,-0.5692837678329253],[0.38132847396681235,-0.6055527805599876],[0.38066928663312904,-0.6435573521921102],[0.37962956884968146,-0.6831973909505742],[0.3781838273925885,-0.7243403995319455],[0.3763015202456066,-0.7668116044134247],[0.37394224417391664,-0.8103783832600879],[0.3710487575380456,-0.8547252441138968],[0.3675363860115458,-0.8994125731285745],[0.3632759853805865,-0.9438062721191148],[0.3580648818087381,-0.9869528000864847],[0.3515746972145897,-1.0273478808003513],[0.34325516991794036,-1.0624968647343795],[0.33216715741214914,-1.0881146445019299],[0.3168109082889655,-1.097163327749017],[0.2957013108677526,-1.0820464090197661],[0.2701860668226187,-1.047762061008717],[0.24387324978683028,-1.0099877697461463],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787], ...

# %% [markdown]
# For training and optimisation, we don't need the whole visualisation, just a simple function that accepts and produces numbers. The `shoot` function just takes a wind speed, angle of release and counterweight mass, and tells us how far the projectile got.

# %%
function shoot(wind, angle, weight)
    Trebuchet.shoot((wind, Trebuchet.deg2rad(angle), weight))[2]
end
# Out:
# shoot (generic function with 1 method)

# %%
shoot(0, 30, 400)
# Out:
# 98.60072421662713

# %% [markdown]
# It's worth playing with these parameters to see the impact they have. How far can you throw the projectile, tweaking only the angle of release?

# %% [markdown]
# There's actually a much better way of aiming the trebuchet. Let's load up a machine learning library, Flux, and see what we can do.

# %%
using Flux, Trebuchet
using Zygote: gradient, forwarddiff

# %% [markdown]
# Firstly, we're going to wrap `shoot` to take a _parameter vector_ (just a list of the three numbers we're interested in). There's also a call to `forwarddiff` here, which tells Flux to differentiate the trebuchet itself using forward mode. The number of parameters is small, so forward mode will be the most efficient way to do it. Otherwise Flux defaults to reverse mode.

# %%
shoot(ps) = forwarddiff(p -> shoot(p...), ps)
# Out:
# shoot (generic function with 2 methods)

# %% [markdown]
# We can get a distance as usual.

# %%
shoot([0, 45, 200])
# Out:
# 82.79904064062524

# %% [markdown]
# But we can also get something much more interesting: *gradients* for each of those parameters with respect to distance.

# %%
gradient(shoot, [0, 45, 200])
# Out:
# ([4.047851617574818, -0.9290087918693511, 0.0579786190513199],)

# %% [markdown]
# What does these numbers mean? The gradient tells us, very roughly, that if we increase a parameter – let's say we make wind speed 1 m/s stronger – distance will also increase by about 4 metres. Let's try that.

# %%
shoot([1, 45, 200])
# Out:
# 86.85243634331043

# %% [markdown]
# Lo and behold, this is indeed about four metres further!

# %%
shoot([1, 45, 200]) - shoot([0, 45, 200])
# Out:
# 4.053395702685194

# %% [markdown]
# So this seems like very useful information if we're trying to aim, or maximise distance. Notice that our gradient for the release angle is negative – increasing angle will decrease distance, so in other words we should probably *decrease* angle if we want more distance. Let's try that.

# %%
shoot([0, 10, 200])
# Out:
# 74.12993018644684

# %% [markdown]
# Oh no, this is actually *less* far than before!

# %% [markdown]
# So if the angle is too shallow, the projectile doesn't spend enough time in the air to gain any distance before hitting the ground. But if it's too high, the projectile doesn't have enough horizontal speed even with lots of time in the air. So we'll have to find a middle ground.
#
# More generally, the lesson here is that the gradient only gives you limited information; it helps us take a small step towards a better aim, and we can keep iterating to get to the best possible aim. For example, we choose a starting angle:

# %%
angle = 45
shoot([0, angle, 200])
# Out:
# 82.79904064062524

# %% [markdown]
# Get a gradient for `angle` alone:

# %%
dangle = gradient(a -> shoot([0, a, 200]), angle)[1]
# Out:
# -0.9290087918693511

# %% [markdown]
# Update the angle, using the learning rate η:

# %%
η = 10
angle += η*dangle
# Out:
# 35.709912081306484

# %%
shoot([0, angle, 200])
# Out:
# 89.00957876560443

# %% [markdown]
# Now we just lather, rinse and repeat! Ok, maybe we should write a loop to automate this a bit.

# %%
for i = 1:10
    dangle = gradient(angle -> shoot([0, angle, 200]), angle)[1] 
    angle += η*dangle
    @show angle
end
shoot([0, angle, 200])
# Out:
# angle = 31.677802040305338
# angle = 30.32109294248436
# angle = 29.860214040031103
# angle = 29.754641642269497
# angle = 29.69112587156686
# angle = 29.687910295032196
# angle = 29.689144047634343
# angle = 29.688684869867625
# angle = 29.688857831339334
# angle = 29.68879296816387
# 90.23898903146821

# %% [markdown]
# Notice how the change in the angle slows down as things converge. Turns out the best angle is about 30 degrees, and we can hit about 90 metres.
#
# We can make this nicely repeatable and get the best angle for any given wind speed.

# %%
function best_angle(wind)
    angle = 45
    objective(angle) = shoot([wind, angle, 200])
    for i = 1:10
        dangle = gradient(objective, angle)[1]
        angle += η*dangle
    end
    return angle
end
# Out:
# best_angle (generic function with 1 method)

# %%
best_angle(0)
# Out:
# 29.688857831339334

# %%
best_angle(10)
# Out:
# 36.96352780153358

# %%
best_angle(-10)
# Out:
# 19.001791819536724

# %% [markdown]
# It turns out that if the wind is on our side, we should just throw the projectile upwards and let it get blown along. If the wind is strong against us, just chuck that stone right into it.

# %%
t = TrebuchetState(release_angle = deg2rad(19), wind_speed = -10)
simulate(t)
visualise(t)
# Out:
# WebIO.Scope(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :span), Any[], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}(), Set(String[]), nothing, WebIO.Asset[WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/utils.js"), WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/animate.js"), WebIO.Asset("css", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/css/basic.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(WebIO.AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x00007fc8b01e8280, Task (runnable) @0x00007fc8b01e8280), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (){createCanvas(this.dom,\"main\"); createOutputBar(this.dom,\"output\",{\"distance\":[0.0,\"m\"],\"height\":[0.0,\"m\"],\"time\":[0.0,\"m\"],\"wind_speed\":[-10.0,\"m/s\"],\"release_angle\":[19.0,\"deg\"]}); return animate(this.dom,\"main\",{\"a\":1.524,\"b\":2.0702016,\"c\":0.5334,\"d\":0.6096,\"e\":2.0826984,\"u\":0.8311896,\"z\":0.037947600000000005},{\"WeightCG\":[[0.36100903572858956,-0.21693215547703187],[0.36100903572858956,-0.21693215547703187],[0.36121169080754156,-0.21826469278794586],[0.36160626877022745,-0.22093699304505876],[0.36218188378492033,-0.22496236727324898],[0.36292728001748314,-0.23036013774467917],[0.363830503182816,-0.23715552725618172],[0.3648784778937668,-0.24537947672165983],[0.3660565171858164,-0.25506834641565734],[0.36734780045985344,-0.26626345094104703],[0.3687328664785807,-0.2790103784357236],[0.37018917737896506,-0.29335805181148567],[0.3716908156413523,-0.3093575043939808],[0.37320837591490047,-0.32706036351445295],[0.37470910504905564,-0.3465170610807403],[0.376157325125258,-0.3677748156896181],[0.3775151461429256,-0.39087545027069015],[0.3787434404287933,-0.41585311481724135],[0.3798030160902147,-0.442731966556288],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.38065590130945604,-0.4715238097076727],[0.3812663642530947,-0.5022266626654668],[0.38160133670624774,-0.5348243481507587],[0.38163097239335414,-0.5692837678329253],[0.38132847396681235,-0.6055527805599876],[0.38066928663312904,-0.6435573521921102],[0.37962956884968146,-0.6831973909505742],[0.3781838273925885,-0.7243403995319455],[0.3763015202456066,-0.7668116044134247],[0.37394224417391664,-0.8103783832600879],[0.3710487575380456,-0.8547252441138968],[0.3675363860115458,-0.8994125731285745],[0.3632759853805865,-0.9438062721191148],[0.3580648818087381,-0.9869528000864847],[0.3515746972145897,-1.0273478808003513],[0.34325516991794036,-1.0624968647343795],[0.33216715741214914,-1.0881146445019299],[0.3168109082889655,-1.097163327749017],[0.2957013108677526,-1.0820464090197661],[0.2701860668226187,-1.047762061008717],[0.24387324978683028,-1.0099877697461463],[0.21832360452963945,-0.9745254458769816],[0.19398773852930973,-0.9425400813487725],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.9361686778635941],[0.18868726872911912,-0.936168 ...

# %% [markdown]
# ## Accuracy Matters

# %% [markdown]
# In optimisation terms, we just created an objective (distance) and tried to maximise that objective. Flinging boulders as far as possible has its moments, but lacks a certain subtlety. What if we instead want to hit a precise target?

# %%
t = TrebuchetState()
simulate(t)
visualise(t, 50)
# Out:
# WebIO.Scope(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :span), Any[], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}(), Set(String[]), nothing, WebIO.Asset[WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/utils.js"), WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/animate.js"), WebIO.Asset("css", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/css/basic.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(WebIO.AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x00007fc8b01e9600, Task (runnable) @0x00007fc8b01e9600), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (){createCanvas(this.dom,\"main\"); createOutputBar(this.dom,\"output\",{\"distance\":[0.0,\"m\"],\"height\":[0.0,\"m\"],\"time\":[0.0,\"m\"],\"wind_speed\":[1.0,\"m/s\"],\"target\":[50,\"m\"],\"release_angle\":[44.99999999999999,\"deg\"]}); return animate(this.dom,\"main\",{\"a\":1.524,\"b\":2.0702016,\"c\":0.5334,\"d\":0.6096,\"e\":2.0826984,\"u\":0.8311896,\"z\":0.037947600000000005},{\"WeightCG\":[[0.36100903572858956,-0.21693215547703187],[0.36100903572858956,-0.21693215547703187],[0.36121169080754156,-0.21826469278794586],[0.36160626877022745,-0.22093699304505876],[0.36218188378492033,-0.22496236727324898],[0.36292728001748314,-0.23036013774467917],[0.363830503182816,-0.23715552725618172],[0.3648784778937668,-0.24537947672165983],[0.3660565171858164,-0.25506834641565734],[0.36734780045985344,-0.26626345094104703],[0.3687328664785807,-0.2790103784357236],[0.37018917737896506,-0.29335805181148567],[0.3716908156413523,-0.3093575043939808],[0.37320837591490047,-0.32706036351445295],[0.37470910504905564,-0.3465170610807403],[0.376157325125258,-0.3677748156896181],[0.3775151461429256,-0.39087545027069015],[0.3787434404287933,-0.41585311481724135],[0.3798030160902147,-0.442731966556288],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.3798030160902148,-0.4427319665562891],[0.38065590130945604,-0.4715238097076727],[0.3812663642530947,-0.5022266626654668],[0.38160133670624774,-0.5348243481507587],[0.38163097239335414,-0.5692837678329253],[0.38132847396681235,-0.6055527805599876],[0.38066928663312904,-0.6435573521921102],[0.37962956884968146,-0.6831973909505742],[0.3781838273925885,-0.7243403995319455],[0.3763015202456066,-0.7668116044134247],[0.37394224417391664,-0.8103783832600879],[0.3710487575380456,-0.8547252441138968],[0.3675363860115458,-0.8994125731285745],[0.3632759853805865,-0.9438062721191148],[0.3580648818087381,-0.9869528000864847],[0.3515746972145897,-1.0273478808003513],[0.34325516991794036,-1.0624968647343795],[0.33216715741214914,-1.0881146445019299],[0.3168109082889655,-1.097163327749017],[0.2957013108677526,-1.0820464090197661],[0.2701860668226187,-1.047762061008717],[0.24387324978683028,-1.0099877697461463],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364,-0.9916666138533787],[0.2307189792496364 ...

# %% [markdown]
# The way to do this is to state the problem in terms of maximising, or minisming, some number – the objective. In this case, an easy way to come up with an objective is to take the difference from our target (gets closer to 0 as aim gets better) and square it (so it's always positive: 0 is the lowest *and* best possible score).

# %% [markdown]
# Here's a modified `best_angle` function that takes a target and tells us the distance it acheived.

# %%
η = 0.1
function best_angle(wind, target)
    angle = 45
    objective(angle) = (shoot([wind, angle, 200]) - target)^2
    for i = 1:30
        dangle = gradient(objective, angle)[1]
        angle -= η*dangle
    end
    return angle, shoot([wind, angle, 200])
end
# Out:
# best_angle (generic function with 2 methods)

# %% [markdown]
# It's pretty accurate!

# %%
best_angle(0, 50)
# Out:
# (67.04270416114778, 49.999999999999645)

# %% [markdown]
# Even when we try to push it, by making wind really strong.

# %%
best_angle(-20, 35)
# Out:
# (21.822435232780407, 34.97455517913783)

# %%
t = TrebuchetState(release_angle = deg2rad(21.8), weight = 200, wind_speed = -20)
simulate(t)
visualise(t, 35)
# Out:
# WebIO.Scope(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :span), Any[], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}(), Set(String[]), nothing, WebIO.Asset[WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/utils.js"), WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/animate.js"), WebIO.Asset("css", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/css/basic.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(WebIO.AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x00007fc8affedae0, Task (runnable) @0x00007fc8affedae0), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (){createCanvas(this.dom,\"main\"); createOutputBar(this.dom,\"output\",{\"distance\":[0.0,\"m\"],\"height\":[0.0,\"m\"],\"time\":[0.0,\"m\"],\"wind_speed\":[-20.0,\"m/s\"],\"target\":[35,\"m\"],\"release_angle\":[21.8,\"deg\"]}); return animate(this.dom,\"main\",{\"a\":1.524,\"b\":2.0702016,\"c\":0.5334,\"d\":0.6096,\"e\":2.0826984,\"u\":0.8311896,\"z\":0.037947600000000005},{\"WeightCG\":[[0.36100903572858956,-0.21693215547703187],[0.36100903572858956,-0.21693215547703187],[0.3611546526879951,-0.21878022160531863],[0.36142598329948633,-0.2224872822599066],[0.3618026411357689,-0.2280709208712819],[0.3622634693958065,-0.23555522005023805],[0.3627861204045109,-0.24497048307947533],[0.36334655868176896,-0.25635274560966],[0.363918566492582,-0.26974298167025146],[0.36447335155441546,-0.28518591809969496],[0.3649793696202525,-0.3027284034020305],[0.3654024716630042,-0.3224173299188754],[0.36570645856879713,-0.3442971749612894],[0.3658540720217947,-0.3684072929326617],[0.36580837310865133,-0.3947791364159209],[0.36553437478422135,-0.42343358773616113],[0.36553437478422124,-0.4234335877361627],[0.36553437478422124,-0.4234335877361627],[0.36553437478422124,-0.4234335877361627],[0.36553437478422124,-0.4234335877361627],[0.36500072430229535,-0.45437852509182786],[0.3641810498879593,-0.48760708426629296],[0.3630544525685545,-0.5230970813457005],[0.3616056653786215,-0.5608091159770607],[0.3598241883700565,-0.6006848196560987],[0.3577024938869795,-0.6426440703575758],[0.35523328015486727,-0.6865802231217228],[0.3524056843850182,-0.7323519219615012],[0.34920014741119954,-0.7797691277330399],[0.3455811433776532,-0.828569076705419],[0.34148599465135,-0.8783737141526049],[0.3368058118094841,-0.9286105114297667],[0.3313493409563827,-0.9783544433112615],[0.3247663869579462,-1.025982094932958],[0.3163651491305704,-1.0683212193215537],[0.3046203195119114,-1.09826407499736],[0.28582683145651766,-1.097685618644704],[0.2543502187232959,-1.034848229586426],[0.22439689990639375,-0.9802926616098828],[0.19633488321584197,-0.9342329598410968],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.17771357514253566,-0.9053119154687773],[0.1777135751425 ...

# %% [markdown]
# ## Siege Weapon Autopilot

# %% [markdown]
# Finally, we go one level more meta by training a neural network to aim the trebuchet for us. Rather than solving a whole optimisation problem every time we want to aim, we can just ask the network for good parameters and get them in constant time.
#
# Here's a simple multi layer perceptron. Its input is two parameters (wind speed and target) and its output is two more (release angle and counterweight mass).

# %%
model = Chain(Dense(2, 16, σ),
              Dense(16, 64, σ),
              Dense(64, 16, σ),
              Dense(16, 2)) |> f64

θ = params(model)

function aim(wind, target)
    angle, weight = model([wind, target])
    angle = σ(angle)*90
    weight = weight + 200
    angle, weight
end

distance(wind, target) = shoot([wind, aim(wind, target)...])
# Out:
# distance (generic function with 1 method)

# %% [markdown]
# The model's initial guesses will be fairly random, and miss the mark.

# %%
aim(0, 70)
# Out:
# (32.42185854988312, 200.16755080887393)

# %%
distance(0, 70)
# Out:
# 64.91102938783358

# %%
using Zygote

# %% [markdown]
# However, just as before, we can define an objective – or loss – and get gradients.

# %%
# Temporary hack to get around lack of Zygote support for try/catch -- ignore :)
using Zygote: @adjoint
function ignore(f)
  try return f()
        catch e; return 0; end
end
@adjoint function ignore(f)
  try Zygote._pullback(__context__, f)
  catch e
    0, ȳ -> nothing
  end
end

# %%
function loss(wind, target)
  #ignore errors since Roots.jl sometimes fails to converge  
  ignore() do  
    (distance(wind, target) - target)^2
  end
end

loss(0, 70)
# Out:
# 75.8992741615871

# %% [markdown]
# This time, though, we'll get gradients for the *model parameters*, and updating these will improve the network's accuracy. This works because we're able to differentiate the *whole program*; the backwards pass propagates errors through the trebuchet simulator and then through the ML model.

# %%
dθ = gradient(θ) do
    loss(0, 70)
end
dθ[model[1].W]
# Out:
# 16×2 Array{Float64,2}:
#   0.0    0.462902
#   0.0    1.37837e-14
#  -0.0  -60.4345
#   0.0    2.12111e-5
#  -0.0   -0.101178
#  -0.0   -7.2158e-8
#  -0.0   -1.64916e-12
#  -0.0   -4.21956e-12
#   0.0    1.56922e-7
#  -0.0   -0.00767872
#  -0.0   -6.6886e-6
#   0.0   91.7457
#  -0.0   -9.12908e-9
#   0.0    2.82436
#   0.0    2.86559e-11
#  -0.0   -1.07605e-6

# %%
DIST  = (20, 100) # Maximum target distance
SPEED = 5         # Maximum wind speed

lerp(x, lo, hi) = x*(hi-lo)+lo

randtarget() = (randn() * SPEED, lerp(rand(), DIST...))
# Out:
# randtarget (generic function with 1 method)

# %%
using Statistics

meanloss() = mean(sqrt(loss(randtarget()...)) for i = 1:100)

opt = ADAM()

dataset = (randtarget() for i = 1:10_000)

Flux.train!(loss, θ, dataset, opt, cb = Flux.throttle(() -> @show(meanloss()), 10))
# Out:
# meanloss() = 36.61854836387758
# meanloss() = 14.838160829062993
# meanloss() = 12.236324336249279
# meanloss() = 9.418266960979055
# meanloss() = 8.554294245112684
# meanloss() = 8.04341447370096
# meanloss() = 9.679374712107153

# %% [markdown]
# After only a few minutes of training, we're getting solid accuracy, even on hard wind speeds and targets. You can run the training loop again to improve the accuracy even further.

# %%
wind, target = -10, 50
angle, mass = aim(wind, target)
t = TrebuchetState(release_angle = deg2rad(angle), weight = mass, wind_speed = wind)
simulate(t)
visualise(t, target)
# Out:
# WebIO.Scope(WebIO.Node{WebIO.DOM}(WebIO.DOM(:html, :span), Any[], Dict{Symbol,Any}()), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}(), Set(String[]), nothing, WebIO.Asset[WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/utils.js"), WebIO.Asset("js", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/js/animate.js"), WebIO.Asset("css", nothing, "/home/aviks/.julia/packages/Trebuchet/ygAwT/assets/css/basic.css")], Dict{Any,Any}(), WebIO.ConnectionPool(Channel{Any}(sz_max:32,sz_curr:0), Set(WebIO.AbstractConnection[]), Base.GenericCondition{Base.AlwaysLockedST}(Base.InvasiveLinkedList{Task}(Task (runnable) @0x00007fc8b7fdf820, Task (runnable) @0x00007fc8b7fdf820), Base.AlwaysLockedST(1))), WebIO.JSString[WebIO.JSString("function () {\n    var handler = ((function (){createCanvas(this.dom,\"main\"); createOutputBar(this.dom,\"output\",{\"distance\":[0.0,\"m\"],\"height\":[0.0,\"m\"],\"time\":[0.0,\"m\"],\"wind_speed\":[-10.0,\"m/s\"],\"target\":[50,\"m\"],\"release_angle\":[38.55252144440616,\"deg\"]}); return animate(this.dom,\"main\",{\"a\":1.524,\"b\":2.0702016,\"c\":0.5334,\"d\":0.6096,\"e\":2.0826984,\"u\":0.8311896,\"z\":0.037947600000000005},{\"WeightCG\":[[0.36100903572858956,-0.21693215547703187],[0.36100903572858956,-0.21693215547703187],[0.3611521092002227,-0.2187979903083651],[0.36141799110625744,-0.2225407070584749],[0.3617859253729672,-0.22817797432330156],[0.3622343786269884,-0.235733923656408],[0.36274062177386057,-0.24523886461643296],[0.3632802379416412,-0.2567287843131826],[0.3638266378122298,-0.2702445341075122],[0.3643506842290739,-0.2858306173229632],[0.3648205405019547,-0.3035335256159672],[0.3652018524261019,-0.3233996268036775],[0.365458344819908,-0.3454726757388022],[0.36555285610209753,-0.36979108713410913],[0.36544875437981983,-0.396385154121602],[0.365091764712705,-0.4235513802653641],[0.365091764712705,-0.4235513802653641],[0.365091764712705,-0.4235513802653641],[0.365091764712705,-0.4235513802653641],[0.36450125247183085,-0.4546123082851812],[0.3636229035225642,-0.48796725416354414],[0.36243654339340103,-0.5235933003037369],[0.36092768168728095,-0.5614503335374695],[0.359086589009738,-0.6014792983385816],[0.35690643766619135,-0.6435993862964338],[0.3543804882927005,-0.6877031926515771],[0.3514982323401834,-0.7336483739374677],[0.3482401706275027,-0.7812433791282203],[0.3445704096745198,-0.8302228320341596],[0.34042522100180495,-0.8802037860734931],[0.3356934199236861,-0.9306039390274135],[0.33017885265654356,-0.9804772962666082],[0.3235201612256022,-1.0281510810295644],[0.31499695320866605,-1.070321375961858],[0.30299897607557214,-1.0994693251562926],[0.283552375260933,-1.0960559653326185],[0.25104265067612314,-1.0277736291563229],[0.2214899038961284,-0.9755483172356144],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.19932602399622684,-0.9394346677893806],[0.1993 ...

# %% [markdown]
# Notice that aiming with a neural net in one shot is significantly faster than solving the optimisation problem; and we only have a small loss in accuracy.

# %%
@time aim(wind, target)
# Out:
#   0.000085 seconds (22 allocations: 2.734 KiB)
# (38.55252144440616, 205.69659410300142)

# %%
@time best_angle(wind, target)
# Out:
#   0.417634 seconds (2.13 M allocations: 102.502 MiB, 12.41% gc time)
# (38.8714753772456, 49.996654315924495)
